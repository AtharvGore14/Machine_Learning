# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sigmoid Function:
# z = 1/ (1 + e ^z)
#
# e = Eulers number ~2.71828
# Range(0,1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"D:\FY\Machine_Learning\07_Logistic_Regression\insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color =  'red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.1)
#X_train means input and y_train means output

# %%
X_train.head
# Out:
# <bound method NDFrame.head of     age
# 7    60
# 24   50
# 5    56
# 26   23
# 3    52
# 4    46
# 14   49
# 12   27
# 20   21
# 25   54
# 1    25
# 23   45
# 6    55
# 22   40
# 8    62
# 16   25
# 0    22
# 19   18
# 13   29
# 21   26
# 11   28
# 2    47
# 10   18
# 15   55>

# %%
X_test
# Out:
#     age
# 9    61
# 17   58
# 18   19

# %%
y_train
# Out:
# 7     1
# 24    1
# 5     1
# 26    0
# 3     0
# 4     1
# 14    1
# 12    0
# 20    0
# 25    1
# 1     0
# 23    1
# 6     0
# 22    1
# 8     1
# 16    1
# 0     0
# 19    0
# 13    0
# 21    0
# 11    0
# 2     1
# 10    0
# 15    1
# Name: bought_insurance, dtype: int64

# %%
y_test
# Out:
# 9     1
# 17    1
# 18    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
#Fit is used to train the model
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 0])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
#Returns the probability of each class
# Out:
# array([[0.05626073, 0.94373927],
#        [0.08047242, 0.91952758],
#        [0.92789886, 0.07210114]])

# %%
model.predict([[40]])
#40 is the age
#here we have to give a 2D array because we have only one feature
# Out:
# d:\FY\Machine_Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
