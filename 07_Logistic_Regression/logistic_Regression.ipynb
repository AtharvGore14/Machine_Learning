# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sigmoid Function:
# z = 1/ (1 + e ^z)
#
# e = Eulers number ~2.71828
# Range(0,1)

# %% [markdown]
# ![image.png](attachment:image.png)
